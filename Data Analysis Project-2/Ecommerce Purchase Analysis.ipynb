# %%
import pandas as pd

# %%
df=pd.read_csv("Ecommerce Purchases.csv")

# %% [markdown]
# # How many people have master card as their Debit card Provider and Made a purchase above 50!

# %%
len(df[(df['CC Provider']=="Mastercard") & (df['Purchase Price']>50)])
# Out:
# 405

# %%
df[(df['CC Provider']=="Mastercard") & (df['Purchase Price']>50)].count()
# Out:
# Address             405
# Lot                 405
# AM or PM            405
# Browser Info        405
# Company             405
# Credit Card         405
# CC Exp Date         405
# CC Security Code    405
# CC Provider         405
# Email               405
# Job                 405
# IP Address          405
# Language            405
# Purchase Price      405
# dtype: int64

# %% [markdown]
# # Find the email of the number with the folloing Credit card number:4664825258997302

# %%
df[df['Credit Card']==4664825258997302]['Email']
# Out:
# 9992    bberry@wright.net
# Name: Email, dtype: object

# %%
df.sample(1)
# Out:
#                                                Address    Lot AM or PM  \
# 917  343 Johnson Crescent Suite 758\nSusanmouth, WY...  85 Lf       AM
#
#                                           Browser Info  \
# 917  Opera/9.84.(X11; Linux i686; it-IT) Presto/2.9...
#
#                      Company       Credit Card CC Exp Date  CC Security Code  \
# 917  Chang, Mueller and Pugh  4608073623922445       08/17               102
#
#        CC Provider                     Email           Job       IP Address  \
# 917  VISA 13 digit  jenniferfowler@gmail.com  Estate agent  244.142.182.162
#
#     Language  Purchase Price
# 917       ru           71.96

# %% [markdown]
# # How many People Purchase During AM and PM?

# %%
df[df['AM or PM']=='AM'].count()
# Out:
# Address             4932
# Lot                 4932
# AM or PM            4932
# Browser Info        4932
# Company             4932
# Credit Card         4932
# CC Exp Date         4932
# CC Security Code    4932
# CC Provider         4932
# Email               4932
# Job                 4932
# IP Address          4932
# Language            4932
# Purchase Price      4932
# dtype: int64

# %%
df[df['AM or PM']=='PM'].count()
# Out:
# Address             5068
# Lot                 5068
# AM or PM            5068
# Browser Info        5068
# Company             5068
# Credit Card         5068
# CC Exp Date         5068
# CC Security Code    5068
# CC Provider         5068
# Email               5068
# Job                 5068
# IP Address          5068
# Language            5068
# Purchase Price      5068
# dtype: int64

# %%
len(df[df['AM or PM']=='AM'])
# Out:
# 4932

# %%
len(df[df['AM or PM']=='PM'])
# Out:
# 5068

# %%
df['AM or PM'].value_counts()
# Out:
# PM    5068
# AM    4932
# Name: AM or PM, dtype: int64

# %%
df['AM or PM'].unique()
# Out:
# array(['PM', 'AM'], dtype=object)

# %%
df2=df.groupby("AM or PM")

# %%
df2.groups
# Out:
# {'AM': [4, 6, 9, 12, 14, 16, 21, 24, 26, 35, 37, 38, 39, 40, 42, 46, 53, 55, 56, 60, 61, 62, 64, 65, 66, 69, 71, 75, 77, 78, 80, 83, 85, 87, 89, 90, 91, 92, 93, 94, 96, 97, 98, 99, 100, 101, 103, 104, 105, 114, 115, 118, 119, 130, 132, 133, 134, 135, 141, 144, 147, 148, 149, 154, 156, 160, 163, 164, 167, 168, 172, 178, 179, 180, 181, 182, 184, 185, 186, 187, 189, 193, 195, 197, 198, 199, 201, 204, 207, 209, 210, 212, 213, 214, 215, 219, 220, 221, 222, 223, ...], 'PM': [0, 1, 2, 3, 5, 7, 8, 10, 11, 13, 15, 17, 18, 19, 20, 22, 23, 25, 27, 28, 29, 30, 31, 32, 33, 34, 36, 41, 43, 44, 45, 47, 48, 49, 50, 51, 52, 54, 57, 58, 59, 63, 67, 68, 70, 72, 73, 74, 76, 79, 81, 82, 84, 86, 88, 95, 102, 106, 107, 108, 109, 110, 111, 112, 113, 116, 117, 120, 121, 122, 123, 124, 125, 126, 127, 128, 129, 131, 136, 137, 138, 139, 140, 142, 143, 145, 146, 150, 151, 152, 153, 155, 157, 158, 159, 161, 162, 165, 166, 169, ...]}

# %%
df['CC Exp Date']
# Out:
# 0       02/20
# 1       11/18
# 2       08/19
# 3       02/24
# 4       10/25
#         ...
# 9995    03/22
# 9996    07/25
# 9997    05/21
# 9998    11/17
# 9999    02/19
# Name: CC Exp Date, Length: 10000, dtype: object

# %% [markdown]
# # How many people have a credit card that will expire in 2020!

# %%
def fun():
    count=0
    for date in df['CC Exp Date']:
        if date.split('/')[1]=='20':
            count=count+1
        print(count) 
        
        
#fun()

# %%
#df[(df['CC Exp Date'].apply(lambda x: x[3:]=='20'))]

# %%
df[(df['CC Exp Date'].apply(lambda x: x[3:]=='20'))].count()
# Out:
# Address             988
# Lot                 988
# AM or PM            988
# Browser Info        988
# Company             988
# Credit Card         988
# CC Exp Date         988
# CC Security Code    988
# CC Provider         988
# Email               988
# Job                 988
# IP Address          988
# Language            988
# Purchase Price      988
# dtype: int64

# %%
len(df[(df['CC Exp Date'].apply(lambda x: x[3:]=='20'))])
# Out:
# 988

# %%
df['Email'].head(3)
# Out:
# 0                 pdunlap@yahoo.com
# 1                anthony41@reed.com
# 2    amymiller@morales-harrison.com
# Name: Email, dtype: object

# %% [markdown]
# # Top 5 Email Providers

# %%
list1=[]
for gmail in df['Email']:
    list1.append(gmail.split('@')[1])

# %%
list1
# Out:
# ['yahoo.com',
#  'reed.com',
#  'morales-harrison.com',
#  'olson-robinson.info',
#  'gmail.com',
#  'gmail.com',
#  'yahoo.com',
#  'parks.info',
#  'rasmussen.com',
#  'hunt-huerta.com',
#  'hotmail.com',
#  'coleman.com',
#  'hotmail.com',
#  'yahoo.com',
#  'yahoo.com',
#  'yahoo.com',
#  'wilson.com',
#  'hall.com',
#  'yahoo.com',
#  'gmail.com',
#  'smith.info',
#  'hotmail.com',
#  'gmail.com',
#  'gardner-meadows.com',
#  'yahoo.com',
#  'mooney.com',
#  'gmail.com',
#  'hotmail.com',
#  'yahoo.com',
#  'yahoo.com',
#  'hotmail.com',
#  'hotmail.com',
#  'atkinson.com',
#  'yahoo.com',
#  'carey-davis.com',
#  'mcdowell.com',
#  'walsh.com',
#  'frederick.info',
#  'boyd-english.org',
#  'wells-carlson.info',
#  'dickerson.com',
#  'yahoo.com',
#  'gmail.com',
#  'martinez-thomas.com',
#  'yahoo.com',
#  'chambers.com',
#  'gmail.com',
#  'glenn.org',
#  'allen.com',
#  'gmail.com',
#  'obrien.org',
#  'cook-castillo.com',
#  'hotmail.com',
#  'yahoo.com',
#  'hotmail.com',
# ...

# %%
df['New']=list1

# %%
df['New1']=df['Email'].apply(lambda x:x.split("@")[1])

# %%
df
# Out:
#                                                 Address    Lot AM or PM  \
# 0     16629 Pace Camp Apt. 448\nAlexisborough, NE 77...  46 in       PM
# 1     9374 Jasmine Spurs Suite 508\nSouth John, TN 8...  28 rn       PM
# 2                      Unit 0065 Box 5052\nDPO AP 27450  94 vE       PM
# 3                 7780 Julia Fords\nNew Stacy, WA 45798  36 vm       PM
# 4     23012 Munoz Drive Suite 337\nNew Cynthia, TX 5...  20 IE       AM
# ...                                                 ...    ...      ...
# 9995      966 Castaneda Locks\nWest Juliafurt, CO 96415  92 XI       PM
# 9996  832 Curtis Dam Suite 785\nNorth Edwardburgh, T...  41 JY       AM
# 9997              Unit 4434 Box 6343\nDPO AE 28026-0283  74 Zh       AM
# 9998               0096 English Rest\nRoystad, IA 12457  74 cL       PM
# 9999     40674 Barrett Stravenue\nGrimesville, WI 79682  64 Hr       AM
#
#                                            Browser Info  \
# ...
